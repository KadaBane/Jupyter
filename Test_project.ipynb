# %%
import pandas as pd
import os

# %%
os. getcwd()
# Out:
# 'C:\\GitRep'

# %%
df = pd.read_csv('C:\\GitRep/Jupyter/data/data.csv',delimiter=';')

# %%
df
# Out:
#        MONTH_DATE  ORIGIN_CITY  ORIGIN_COUNTRY ORIGIN_CONTINENT  \
# 0      01.12.2023    Amsterdam     Netherlands           Europe
# 1      01.12.2023    St, Louis   United States    North America
# 2      01.12.2023       London  United Kingdom           Europe
# 3      01.12.2023       London  United Kingdom           Europe
# 4      01.12.2023    Amsterdam     Netherlands           Europe
# ...           ...          ...             ...              ...
# 22699  01.01.2023        Abuja         Nigeria           Africa
# 22700  01.01.2023    St, Louis   United States    North America
# 22701  01.01.2023   Manchester  United Kingdom           Europe
# 22702  01.01.2023  Los Angeles   United States    North America
# 22703  01.01.2023    Cape Town    South Africa           Africa
#
#       MAIN_DESTINATION_CITY MAIN_DESTINATION_COUNTRY  \
# 0                    Lisbon                 Portugal
# 1                     Accra                    Ghana
# ...
